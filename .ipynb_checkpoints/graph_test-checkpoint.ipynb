# %%
from graph_parser import *
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
test_map ="""wwwwwwwwwwwwwwweeewwwwwwwwwwwwwww
wb                            b w
wb                            b w
wb                            b w
wb   wwwwwwwww    wwwwwwwwww  b w
wb   ws b    w    ws  b    w  b w
wb   w            w        w    w
wb   w2           w        w    w
wb   w       w  b w        w    w
wb   wwwwwwwww  b w             w
wb              b w             w
w                 wwwwwwwwww    w
w                               w
wwwwwwwwwwwww                   w
e                               w
e                             b w
e                             b w
wwwwwwwwwwwww                 b w
ws   b      w                 b w
w           w                 b w
w                             b w
w                             b w
w                             b w
w           w                 b w
w           w                 b w
w           w                 b w
w           w                   w
w1          wr                  w
w           w                   w
wwwwwwwwwwwwwwwwwwwweeewwwwwwwwww"""

# %%
test_map ="""wwwwwwwwwwwwwweeewwwwwwwwwwwww
wb s   b    w     w         bw
wb          w               bw
wb                          bw
wb                wb        bw
wb          w     w      s  bw
wwwwwwwwwwwww     wwwwwwwwwwww
w 2   b     wb              bw
w           wb              bw
w           w     wb        bw
wb                w         bw
wb                wwwwwwwwwwww
wwwwwwwwwwwww     wb        bw
w                 w         bw
e                 w         bw
e                            w
e                          3 w
wwwwwwwwwwwww     wwwwwwwwwwww
ws   b      w               bw
w           w               bw
w                 w         bw
wb                w         bw
wb          w     w         bw
wwwwwwwwwwwww     wwwwwwwwwwww
wb                          bw
wb                           w
w           w      w         w
w1        b wr     wb        w
w           w      wb        w
wwwwwwwwwwwwwwweeewwwwwwwwwwww"""

# %%
test_map ="""wweeeww
w r   w
w     w
w     w
w     w
ww    w
ww    w
ww    w
ww    w
ww    w
w     w
w     w
w     w
w     w
w     w
w     w
w     w
w     w
w     w
w     w
w     w
w     w
w     w
w     w
w     w
w     w
w     w
w1    w
w     w
wwwwwww"""

# %%
G, walls = parse_map(test_map)

# %%
from matplotlib import pyplot as plt


plt.figure(figsize=(30,30))
pos = {(x,y):(x,-y) for x,y in G.nodes()}
colors = {'e':(0.8,0.8,0.8),'s':(0.9,0.9,0.9),'b':(0.8,0.6,0.6),'r':(0,0.6,0.6),'goal':(0,0.6,0.9),'f':(0.6,0.8,0.6)}
col = [colors[att] if att!=None else (0.6,0.8,0.6) for (x,y),att in G.nodes('type')]
lab = {(x,y):str(x)+','+str(y) for x,y in G.nodes}
nx.draw_networkx(G, labels = lab,
        pos=pos, 
        node_color=col,
        alpha = 1,
        with_labels=True,
        node_size=1200,
        edge_color='grey',
        font_weight = 'normal')
